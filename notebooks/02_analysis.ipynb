# %% [markdown]
# # In-Depth Analysis
#
# Now that we've explored the data, let's dig deeper into the business questions.
#
# ## Key Questions to Answer:
# 1. Which products perform best in each store?
# 2. How do stores compare in overall performance?
# 3. What are the vendor trends?
# 4. Are there any surprising patterns?

# %% [markdown]
# ## 1. Setup & Import Data

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('..')

# Load your cleaned data
df = pd.read_csv('../data/raw/synthetic_beverage_sales_data.csv')

print(f"Data loaded: {df.shape[0]} rows, {df.shape[1]} columns")
print(f"\nColumns: {df.columns.tolist()}")

# %% [markdown]
# ## 2. Explore Column Names
#
# First, let's see what columns we have and map them to what we need.

# %%
# Display first few rows to understand the data structure
print(df.head(10))
print("\nColumn names:")
print(df.columns.tolist())

# %% [markdown]
# ## 3. Basic Aggregations
#
# Adjust the column names below based on what you found above.

# %%
# Example aggregations - modify column names as needed
# If your columns are different, update the names below

print("\n=== INITIAL ANALYSIS ===")
print(f"\nTotal Records: {len(df)}")
print(f"Date Range: {df.iloc[:, 0].min()} to {df.iloc[:, 0].max()}")

# Show summary statistics for numeric columns
print("\nNumeric Columns Summary:")
print(df.describe())

# %% [markdown]
# ## 4. Group By Analysis
#
# Create groupby analysis based on your actual columns.

# %%
# Display unique values in each column to understand the data better
for col in df.columns:
    if df[col].dtype == 'object':
        unique_count = df[col].nunique()
        print(f"\n{col}: {unique_count} unique values")
        if unique_count <= 20:
            print(df[col].unique())

# %% [markdown]
# ## 5. Custom Analysis
#
# Based on your column names, create custom aggregations.

# %%
# Example: If you have a 'quantity' and 'product' column
# top_products = df.groupby('product_name')['quantity'].sum().sort_values(ascending=False).head(10)
# print("Top 10 Products:")
# print(top_products)

# Try different groupby operations here
print("Modify this cell based on your actual column names!")

# %% [markdown]
# ## Next Steps
#
# - Update the column names in this notebook based on your actual data
# - Create meaningful groupby analysis
# - Move to `03_visualizations.ipynb` to create charts
